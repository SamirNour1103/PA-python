# %% [markdown]
# <a href="https://colab.research.google.com/github/SamirNour1103/PA-python/blob/main/prova_20mim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1)	Detector de Fases da Lua (Situação hipotética)
# Faça um programa que pergunte o dia do mês (1 a 31) Não aceite valores fora desse intervalo.
# Baseado no dia, informe a provável fase da lua:
#
# •  Dia 1 a 7: Lua Nova
#
# •  Dia 8 a 14: Quarto Crescente
#
# •  Dia 15 a 21: Lua Cheia
#
# •  Dia 22 a 29: Quarto Minguante
#
# •  Dia 30 ou mais: Início de novo ciclo lunar

# %%
dia = int(input("Digite o dia do mês: "))

if (dia >= 1 and dia <= 31):
  print("Dia válido")

  if (dia >= 1 and dia <= 7):
    print("Lua Nova")

  elif (dia >= 8 and dia <= 14):
    print("Quarto Crescente")

  elif (dia >= 15 and dia <= 21):
    print("Lua Cheia")

  elif (dia >= 22 and dia <= 29):
    print("Quarto Minguante")

  else:
    print("Início de novo ciclo lunar")

else:
  print("Dia inválido")
# Out:
# Digite o dia do mês: 31
# Dia válido
# Início de novo ciclo lunar

# %% [markdown]
# 2)	Crie um programa que simule a entrada de um jogador em uma batalha de RPG. O usuário deverá informar:
#
# •	Sua classe: "mago", "guerreiro" ou "arqueiro" (deve dar erro se as entradas forem diferentes dessas.
#
# •	Sua energia (valor de 0 a 100)
# Regras de entrada:
#
# •	Magos: precisam ter energia > 60
#
# •	Guerreiros: energia > 40
#
# •	Arqueiros: energia > 50
#
# Se puder entrar na batalha, o programa deve calcular um dano base diferente para cada classe:
#
# •	Mago: dano = energia × 1.5
#
# •	Guerreiro: dano = energia × 2
#
# •	Arqueiro: dano = energia × 1.2
#
# O programa deve exibir:
#
# •	Se o jogador pode ou não entrar
#
# •	E, se puder, mostrar seu dano base
# calculado

# %%
energia = int(input("Digite sua energia: "))

if (energia >= 0 and energia <= 100):
  print('Entrou no jogo')
  classe = int(input("Digite sua classe \n 1 para Mago \n 2 para Guerreiro \n 3 para Arqueiro: "))


  if( classe == 1):
    energia = energia * 1.5
    if(energia >60):
      print('O Mago supremo entrou na batalha com ', energia)
    else:
     print(f'Sem energia suficiente para entrar na batalha estando só com {energia} de energia')


  elif( classe == 2):
    energia = energia * 2
    if(energia > 40):
      print('O Super Guerreiro entrou na batalha com ', energia)
    else:
      print(f'Sem energia suficiente para entrar na batalha estando só com {energia} de energia')


  elif( classe == 3):
    energia = energia * 1.2
    if(energia > 50):
      print('O Super Arqueiro entrou na batalha com ', energia)
    else:
      print(f'Sem energia suficiente para entrar na batalha estando só com {energia} de energia')

  else:
    print("Classe inválida")


else:
  print("Energia inválida ela deve estar entre 0 e 100"  )
# Out:
# Digite sua energia: 70
# Entrou no jogo
# Digite sua classe
#  1 para Mago
#  2 para Guerreiro
#  3 para Arqueiro: 5
# Classe inválida

# %% [markdown]
# Descrição do Algoritmo:
# 1. Início
#
# •	Solicita-se a renda familiar mensal (em reais).
#
# 2. Validação da Renda
#
# •	Se a renda familiar for menor que 0, exibir:
#
# ➤ "Renda inválida
#
# •	Se a renda familiar for maior que R$ 5.000, exibir:
#
# ➤ "Não participa da bolsa. Só participam candidatos com renda menor ou igual a R$ 5.000."
#
# 3. Tipo de Escola
#
# •	Solicitar o tipo de escola do candidato: "pública" ou "particular".
#
# •	Se for outro valor, exibir:
#
# ➤ "Tipo de escola inválido"
#
# ➤ Encerrar o programa.
#
# 4. Notas Anuais
#
# •	Solicitar as três últimas notas anuais nas disciplinas:
#
# o	Matemática
#
# o	Português
#
# o	Conhecimentos Gerais
#
# •	Para cada nota, validar se está entre 1 e 10:
#
# o	Se alguma estiver fora desse intervalo, exibir erro específico:
#
# ➤ "Nota inválida. Reinicie o preenchimento."
#
# ➤ Encerrar o programa.
#
# •	Calcular a média simples das três notas.
#
# Observação: Essa média poderá ser superior a 10 após os bônus.
#
# Processamento por Tipo de Escola e Média
# Se a escola for pública:
#
# Média ≥ 8:
#
# •	Aumentar a média em 20%;
#
# •	Se a renda < R$ 3.000, aplicar mais 15% sobre o novo valor da média.
# Média ≥ 6 e < 8:
#
# •	Aumentar a média em 10%;
#
# •	Se a renda < R$ 3.000, aplicar mais 5% sobre o novo valor da média.
# Média < 6:
#
# •	Exibir:
#
# ➤ "Não concorre à bolsa por nota baixa."
#
# Se a escola for particular:
#
# Média ≥ 8:
#
# •	Aumentar a média em 5%;
#
# •	Se a renda < R$ 3.000, aplicar mais 15% sobre o novo valor da média.
#
# Média ≥ 6 e < 8:
#
# •	Aumentar a média em 2,5%;
#
# •	Se a renda < R$ 3.000, aplicar mais 2% sobre o novo valor da média.
# Média < 6:
#
# •	Exibir:
#
# ➤ "Não concorre à bolsa por nota baixa."

# %%
renda = float(input('Me dia a sua renda familiar mensal: '))

if (renda > 0):
  if (renda <= 5000):

    escola = int(input('Me diga sua escola sendo \n 1 para escolas públicas \n 2 para escolas particulares: '))

    if (escola == 1 or escola == 2):

      nota1 = float(input("Me diga sua última nota anual na disciplina de Matemática: "))
      nota2 = float(input("Me diga sua última nota anual na disciplina de Português: "))
      nota3 = float(input("Me diga sua última nota anual na disciplina de Conhecimentos Gerais: "))

      if (nota1 >= 1 and nota1 <= 10):
        print("Nota 1 válida")

      else:
        print("nota 1 inválida")

      if (nota2 >= 1 and nota2 <= 10):
        print("Nota 2 válida")

      else:
        print("nota 2 inválida")

      if (nota3 >= 1 and nota2 <= 10):
        print("Nota 3 válida")

      else:
        print("nota inválida")

      if (escola == 1):
        media = (nota1 + nota2 + nota3) /3
        if (media > 8):
          media = media + 0.2
          if (renda < 3000):
            media = media + 0.15
          print("Sua nova média é de", media)
        elif (media > 6 and media < 8):
          media = media + 0.1
          if (renda < 3000):
            media = media + 0.05
            print("Sua nova média é de", media)
        else:
          print("Não concorre a bolsa")

    else:
      print("Tipo de escola inválido \nPrograma encerrado.")

  else:
    print("Não participa da bolsa. Só participam candidatos com renda menor ou igual a R$ 5.000.")
else:
  print("Renda inválida")
# Out:
# Me dia a sua renda familiar mensal: 1111
# Me diga sua escola sendo
#  1 para escolas públicas
#  2 para escolas particulares: 1
# Me diga sua última nota anual na disciplina de Matemática: 9
# Me diga sua última nota anual na disciplina de Português: 9
# Me diga sua última nota anual na disciplina de Conhecimentos Gerais: 9
# Nota 1 válida
# Nota 2 válida
# Nota 3 válida
# Sua nova média é de 9.35
